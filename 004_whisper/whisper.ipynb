# %% [markdown]
# # 004_Whisper 실습

# %% [markdown]
# ## 패키지 설치하기
#    - openai-whisper 패키지 설치하기
#    - 참고: https://github.com/openai/whisper

# %%
# !pip install -U openai-whisper

# %% [markdown]
# ## 패키지

# %%
from IPython.display import Audio
from openai import OpenAI
import whisper

# %% [markdown]
# ##모델 불러오기

# %%
model = whisper.load_model("large")
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [01:22<00:00, 37.6MiB/s]

# %% [markdown]
# ##테스트 오디오(음성) 파일

# %%
#audio_path = "examples/example.wav"
audio_path = "001.m4a"
Audio(filename=audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##추론하기

# %%
result = model.transcribe(audio_path)
result["text"]
# Out:
# ' 경기와 강원 북부 지역을 중심으로 지진동이 느껴졌을 것으로 보인다.'
